# %%
# Import dependencies
import pandas as pd
import os

# %%
file_path = ['trip_data/JC-201801-citibike-tripdata.csv',
        'trip_data/JC-201802-citibike-tripdata.csv',
        'trip_data/JC-201803-citibike-tripdata.csv',
        'trip_data/JC-201804-citibike-tripdata.csv',
        'trip_data/JC-201805-citibike-tripdata.csv',
        'trip_data/JC-201806-citibike-tripdata.csv']

# %%
citibike_df = pd.DataFrame()

# %%
# Loop through the list of files and concatonate all data to the dataframe
for file in file_path:
    data = pd.read_csv(file)
    citibike_df = pd.concat([citibike_df, data], axis=0, ignore_index=True)

# %%
citibike_df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1                550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2                510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3                354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4                250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
# ...              ...                       ...                       ...
# 143912          1227  2018-06-30 20:46:55.7500  2018-06-30 21:07:22.9730
# 143913          1219  2018-06-30 20:47:02.7610  2018-06-30 21:07:22.1720
# 143914          1227  2018-06-30 20:47:03.1250  2018-06-30 21:07:30.3560
# 143915           252  2018-06-30 21:13:35.6890  2018-06-30 21:17:48.5690
# 143916           652  2018-06-30 22:03:44.8150  2018-06-30 22:14:37.5310
#
#         start station id start station name  start station latitude  \
# ...

# %%
# Check for missing values in each column
missing_values = citibike_df.isnull().sum()
print(missing_values)
# Out:
# tripduration               0
# starttime                  0
# stoptime                   0
# start station id           0
# start station name         0
# start station latitude     0
# start station longitude    0
# end station id             0
# end station name           0
# end station latitude       0
# end station longitude      0
# bikeid                     0
# usertype                   0
# birth year                 0
# gender                     0
# dtype: int64

# %%
# Store the dataframe as CSV file
citibike_df.to_csv('trip_data/2018jc_data.csv', index=False)

# %%
citibike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143917 entries, 0 to 143916
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             143917 non-null  int64
#  1   starttime                143917 non-null  object
#  2   stoptime                 143917 non-null  object
#  3   start station id         143917 non-null  int64
#  4   start station name       143917 non-null  object
#  5   start station latitude   143917 non-null  float64
#  6   start station longitude  143917 non-null  float64
#  7   end station id           143917 non-null  int64
#  8   end station name         143917 non-null  object
#  9   end station latitude     143917 non-null  float64
#  10  end station longitude    143917 non-null  float64
#  11  bikeid                   143917 non-null  int64
#  12  usertype                 143917 non-null  object
# ...
